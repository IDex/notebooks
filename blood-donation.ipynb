# %%
# %matplotlib inline
import scipy as sc
import pandas as pd
import ggplot as gg
from sklearn import datasets, model_selection, decomposition, ensemble, neural_network, svm,\
preprocessing, pipeline, linear_model
from tensorflow.contrib import learn as ln
import tensorflow as tf
# Out:
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin, TransformerMixin
from sklearn.utils.validation import check_X_y, check_array, check_is_fitted
from sklearn.utils.multiclass import unique_labels

class ELMClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, h=10, af=sc.special.expit):
        self.h = h
        self.af = af
        self.binarizer = preprocessing.LabelBinarizer()

    def fit(self, X, y):
        # Check that X and y have correct shape
        X, y = check_X_y(X, y)
        # Store the classes seen during fit
        self.classes_ = unique_labels(y)
        y_bin = self.binarizer.fit_transform(y)
        self.W0=sc.stats.norm().rvs([X.shape[1],self.h])
        X0=self.af(self.W0.T@X.T)
        self.W=sc.linalg.pinv(X0.T)@y_bin
        return self

    def predict(self, X):
        # Check is fit had been called
        check_is_fitted(self, ['W',])
        # Input validation
        X = check_array(X)
        raw_predictions = self.W.T@self.af(self.W0.T@X.T)
        class_predictions = self.binarizer.inverse_transform(raw_predictions.T)
        return class_predictions

# %%
Xo,ro=datasets.load_digits(return_X_y=True)
Xo.shape
# Out:
# (1797, 64)

# %%
Xo,ro=datasets.load_iris(return_X_y=True)
Xo.shape
# Out:
# (150, 4)

# %%
data=pd.read_csv('transfusion.data')
ro = data[data.columns[4]]
Xo = data[data.columns[:4]]
Xo.shape
# Out:
# (748, 4)

# %%
test_data = pd.read_csv('5c9fa979-5a84-45d6-93b9-543d1a0efc41.csv')
data = pd.read_csv('9db113a1-cdbe-4b1c-98c2-11590f124dd8.csv')
ro = data[data.columns[5]]
Xo = data[data.columns[:5]]
Xot = test_data

# %%
ro[0]
# Out:
# 1

# %%
X,Xt,r,rt = model_selection.train_test_split(Xo,ro,test_size=.2)

# %%
feature_columns = [tf.contrib.layers.real_valued_column("", dimension=5)]

classifier = tf.contrib.learn.DNNClassifier(feature_columns=feature_columns,
                                            hidden_units=[5, 5, 5,],
                                            n_classes=2,
                                            model_dir="/tmp/blood_model2",
                                            config=tf.contrib.learn.RunConfig(save_checkpoints_secs=1),
                                           )

validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    Xt,
    rt,
    every_n_steps=50,
    early_stopping_rounds=200,
)



classifier.fit(x=X,
               y=r,
               steps=200000,
               monitors=[validation_monitor]
              )

accuracy_score = classifier.evaluate(x=Xt,
                                         y=rt)["accuracy"]

print('Accuracy: {0:f}'.format(accuracy_score))
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fefb6a5f940>, '_master': '', '_num_ps_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 1, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000}
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# WARNING:tensorflow:From <ipython-input-24-44f9618b376a>:22: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-24-44f9618b376a>:22: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/blood_model2/model.ckpt.
# INFO:tensorflow:loss = 0.69369, step = 1
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-07-08:09:44
# INFO:tensorflow:Finished evaluation at 2017-07-07-08:09:44
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, global_step = 1, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.492082, loss = 0.684807, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 50): accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.492082, loss = 0.684807, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0, global_step = 1
# INFO:tensorflow:Saving checkpoints for 51 into /tmp/blood_model2/model.ckpt.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-07-08:09:45
# INFO:tensorflow:Finished evaluation at 2017-07-07-08:09:45
# INFO:tensorflow:Saving dict for global step 51: accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, global_step = 51, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.37627, loss = 0.589677, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 100): accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.37627, loss = 0.589677, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0, global_step = 51
# INFO:tensorflow:Saving checkpoints for 101 into /tmp/blood_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 39.7392
# INFO:tensorflow:loss = 0.572757, step = 101
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-07-08:09:46
# INFO:tensorflow:Finished evaluation at 2017-07-07-08:09:46
# INFO:tensorflow:Saving dict for global step 101: accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, global_step = 101, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.332756, loss = 0.566541, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step
into /tmp/blood_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 36.942
# INFO:tensorflow:loss = 0.552579, step = 2101
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-07-08:10:35
# INFO:tensorflow:Finished evaluation at 2017-07-07-08:10:35
# INFO:tensorflow:Saving dict for global step 2101: accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, global_step = 2101, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.241306, loss = 0.542789, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 2150): accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.241306, loss = 0.542789, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0, global_step = 2101
# INFO:tensorflow:Saving checkpoints for 2151 into /tmp/blood_model2/model.ckpt.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-07-08:10:36
# INFO:tensorflow:Finished evaluation at 2017-07-07-08:10:37
# INFO:tensorflow:Saving dict for global step 2151: accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, global_step = 2151, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.241306, loss = 0.542789, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 2200): accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.241306, loss = 0.542789, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0, global_step = 2151
# INFO:tensorflow:Saving checkpoints for 2201 into /tmp/blood_model2/model.ckpt.
# INFO:tensorflow:global_step/sec: 41.0694
# INFO:tensorflow:loss = 0.552579, step = 2201
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:657: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-07-08:10:38
# INFO:tensorflow:Finished evaluation at 2017-07-07-08:10:38
# INFO:tensorflow:Saving dict for global step 2201: accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, global_step = 2201, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.241306, loss = 0.542789, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 2250): accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.241306, loss = 0.542789, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0, global_step = 2201
# INFO:tensorflow:Stopping. Best step: 2050 with loss = 0.5427893400192261.
# INFO:tensorflow:Saving checkpoints for 2250 into /tmp/blood_model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.552579.
# WARNING:tensorflow:From <ipython-input-24-44f9618b376a>:26: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-24-44f9618b376a>:26: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /home/ide/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2017-07-07-08:10:38
# INFO:tensorflow:Finished evaluation at 2017-07-07-08:10:39
# INFO:tensorflow:Saving dict for global step 2250: accuracy = 0.767241, accuracy/baseline_label_mean = 0.232759, accuracy/threshold_0.500000_mean = 0.767241, auc = 0.5, global_step = 2250, labels/actual_label_mean = 0.232759, labels/prediction_mean = 0.241306, loss = 0.542789, precision/positive_threshold_0.500000_mean = 0.0, recall/positive_threshold_0.500000_mean = 0.0
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# Accuracy: 0.767241

# %% [markdown]
# rscv=model_selection.RandomizedSearchCV(
#     pipeline.make_pipeline(
#         ensemble.RandomForestClassifier(),
#     ),
#     dict(
#         randomforestclassifier__n_estimators=sc.stats.randint(1,100),
#         #randomforestclassifier__min_samples_split=sc.stats.randint(2,10),
#         randomforestclassifier__max_features=sc.stats.uniform(0,1),
#     ),
#     n_iter=30,
#     n_jobs=-1,
#     cv=10,
#     verbose=True,
# )
# rscv.fit(X,r)
# rscv.score(Xt,rt)

# %%
rscv=ensemble.GradientBoostingClassifier(n_estimators=100)
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.85344827586206895

# %%
res=rscv.predict_proba(Xot).T[1]
subm=pd.read_csv('BloodDonationSubmissionFormat.csv')
subm[subm.columns[1]] = res

# %%
subm=subm.set_index(subm.columns[0])

# %%
subm.to_csv('subm.csv')

# %%
rscv=ensemble.GradientBoostingClassifier(n_estimators=300)
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.7068965517241379

# %%
rscv=neural_network.MLPClassifier()#solver='adam', hidden_layer_sizes=[1000,])
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.74137931034482762

# %%
rscv=pipeline.make_pipeline(preprocessing.StandardScaler(),neural_network.MLPClassifier([100,100],max_iter=10000))
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.77586206896551724

# %%
rscv=pipeline.make_pipeline(preprocessing.StandardScaler(),ELMClassifier(100))
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.71551724137931039

# %%
rscv=pipeline.make_pipeline(preprocessing.StandardScaler(),svm.SVC(kernel='rbf'))
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.75862068965517238

# %%
rscv=pipeline.make_pipeline(preprocessing.StandardScaler(),svm.SVC(kernel='poly'))
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.73275862068965514

# %%
rscv=pipeline.make_pipeline(preprocessing.StandardScaler(),svm.SVC(kernel='linear'))
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# 0.74137931034482762

# %%
rscv=model_selection.RandomizedSearchCV(
    pipeline.make_pipeline(
        preprocessing.StandardScaler(),
        neural_network.MLPClassifier(max_iter=10000),
    ),
    dict(
        mlpclassifier__solver=['lbfgs', 'adam'],
        mlpclassifier__hidden_layer_sizes=[[x,] for x in range(1,10+1)],
    ),
    n_iter=5,
    n_jobs=-1,
    cv=10,
    verbose=True,
)
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  1.5min finished
# 0.29310344827586204

# %%
rscv=model_selection.RandomizedSearchCV(
    ensemble.GradientBoostingClassifier(),
    dict(
        n_estimators=sc.stats.randint(10,200),
    ),
    n_iter=50,
    n_jobs=-1,
    cv=10,
    verbose=True,
)
rscv.fit(X,r)
rscv.score(Xt,rt)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   16.8s finished
# 0.85344827586206895

# %%
rscv.best_estimator_
res=rscv.predict_proba(Xot).T[1]
subm=pd.read_csv('BloodDonationSubmissionFormat.csv')
subm[subm.columns[1]] = res

# %%
b = rscv.best_estimator_
b.fit(Xo,ro)
b.predict_proba(Xot)
# Out:
# array([[ 0.62254911,  0.37745089],
#        [ 0.86480561,  0.13519439],
#        [ 0.81282191,  0.18717809],
#        [ 0.71282796,  0.28717204],
#        [ 0.46083394,  0.53916606],
#        [ 0.18081765,  0.81918235],
#        [ 0.72417429,  0.27582571],
#        [ 0.93043319,  0.06956681],
#        [ 0.96724053,  0.03275947],
#        [ 0.9597238 ,  0.0402762 ],
#        [ 0.88154948,  0.11845052],
#        [ 0.85006784,  0.14993216],
#        [ 0.59568099,  0.40431901],
#        [ 0.80166423,  0.19833577],
#        [ 0.85407378,  0.14592622],
#        [ 0.89636462,  0.10363538],
#        [ 0.86770609,  0.13229391],
#        [ 0.67701374,  0.32298626],
#        [ 0.91136885,  0.08863115],
#        [ 0.76066304,  0.23933696],
#        [ 0.36772679,  0.63227321],
#        [ 0.54944599,  0.45055401],
#        [ 0.48929831,  0.51070169],
#        [ 0.84504764,  0.15495236],
#        [ 0.76399224,  0.23600776],
#        [ 0.69032499,  0.30967501],
#        [ 0.68030616,  0.31969384],
#        [ 0.89237922,  0.10762078],
#        [ 0.79299157,  0.20700843],
#        [ 0.62254911,  0.37745089],
#        [ 0.69032499,  0.30967501],
#        [ 0.81586308,  0.18413692],
#        [ 0.84828954,  0.15171046],
#        [ 0.72134853,  0.27865147],
#        [ 0.81937357,  0.18062643],
#        [ 0.80735749,  0.19264251],
#        [ 0.77212059,  0.22787941],
#        [ 0.87381649,  0.12618351],
#        [ 0.58601536,  0.41398464],
#        [ 0.84792469,  0.15207531],
#        [ 0.78312658,  0.21687342],
#        [ 0.89597112,  0.10402888],
#        [ 0.96955297,  0.03044703],
#        [ 0.43984526,  0.56015474],
#        [ 0.86192248,  0.13807752],
#        [ 0.84754133,  0.15245867],
#        [ 0.77094904,  0.22905096],
#        [ 0.90250601,  0.09749399],
#        [ 0.93043319,  0.06956681],
#        [ 0.80134263,  0.19865737],
#        [ 0.58589154,  0.41410846],
#        [ 0.33311357,  0.66688643],
#        [ 0.93528251,  0.06471749],
#        [ 0.54585082,  0.45414918],
#        [ 0.93994741,  0.06005259],
#        [ 0.72134853,  0.27865147],
#        [ 0.82765166,  0.17234834],
#        [ 0.89166516,  0.10833484],
#        [ 0.92258077,  0.07741923],
#        [ 0.43116464,  0.56883536],
#        [ 0.55508337,  0.44491663],
#        [ 0.37211634,  0.62788366],
#        [ 0.81282191,  0.18717809],
#        [ 0.68030616,  0.31969384],
#        [ 0.73463951,  0.26536049],
#        [ 0.81282191,  0.18717809],
#        [ 0.93202028,  0.06797972],
#        [ 0.8815121 ,  0.1184879 ],
#        [ 0.50595272,  0.49404728],
#        [ 0.94018285,  0.05981715],
#        [ 0.84828954,  0.15171046],
#        [ 0.8633689 ,  0.1366311 ],
#        [ 0.41256037,  0.58743963],
#        [ 0.80735749,  0.19264251],
#        [ 0.82618212,  0.17381788],
#        [ 0.88702705,  0.11297295],
#        [ 0.69378799,  0.30621201],
#        [ 0.90146583,  0.09853417],
#        [ 0.8397147 ,  0.1602853 ],
#        [ 0.33311357,  0.66688643],
#        [ 0.89636462,  0.10363538],
#        [ 0.91982788,  0.08017212],
#        [ 0.83336633,  0.16663367],
#        [ 0.58036868,  0.41963132],
#        [ 0.68149388,  0.31850612],
#        [ 0.86035383,  0.13964617],
#        [ 0.890209  ,  0.109791  ],
#        [ 0.75868404,  0.24131596],
#        [ 0.69032499,  0.30967501],
#        [ 0.74640489,  0.25359511],
#        [ 0.76066304,  0.23933696],
#        [ 0.93754004,  0.06245996],
#        [ 0.8628521 ,  0.1371479 ],
#        [ 0.84504764,  0.15495236],
#        [ 0.31175956,  0.68824044],
#        [ 0.91685027,  0.08314973],
#        [ 0.85789631,  0.14210369],
#        [ 0.64754747,  0.35245253],
#        [ 0.732022  ,  0.267978  ],
#        [ 0.91386232,  0.08613768],
#        [ 0.80166423,  0.19833577],
#        [ 0.95414594,  0.04585406],
#        [ 0.84573019,  0.15426981],
#        [ 0.48929831,  0.51070169],
#        [ 0.95464301,  0.04535699],
#        [ 0.67169317,  0.32830683],
#        [ 0.86091989,  0.13908011],
#        [ 0.86192248,  0.13807752],
#        [ 0.91569887,  0.08430113],
#        [ 0.4092081 ,  0.5907919 ],
#        [ 0.92372761,  0.07627239],
#        [ 0.21543481,  0.78456519],
#        [ 0.81252145,  0.18747855],
#        [ 0.87361145,  0.12638855],
#        [ 0.92924343,  0.07075657],
#        [ 0.85068898,  0.14931102],
#        [ 0.94938229,  0.05061771],
#        [ 0.93616254,  0.06383746],
#        [ 0.81172836,  0.18827164],
#        [ 0.88619587,  0.11380413],
#        [ 0.76341737,  0.23658263]])

# %% [markdown]
# rscv=svm.SVC(kernel='poly')
# rscv.fit(X,r)
# rscv.score(Xt,rt)

# %% [markdown]
# res = model_selection.cross_val_score(
#     svm.SVC(kernel='linear'),
#     Xo,
#     ro,
#     cv=10
# )
# sc.mean(res)

# %%
res = model_selection.cross_val_score(
    ensemble.RandomForestClassifier(2000),
    Xo,
    ro,
    cv=10
)
sc.mean(res)
# Out:
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)

# %%
res = model_selection.cross_val_score(
    ensemble.GradientBoostingClassifier(n_estimators=20),
    Xo,
    ro,
    cv=10
)
sc.mean(res)
# Out:
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.3058525868184323

# %%
res = model_selection.cross_val_score(
    neural_network.MLPClassifier(max_iter=10000, hidden_layer_sizes=[200,]),
    Xo,
    ro,
    cv=10
)
sc.mean(res)
# Out:
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.073761666416201688

# %%
res = model_selection.cross_val_score(
    ELMClassifier(h=10),
    Xo,
    ro,
    cv=10
)
sc.mean(res)
# Out:
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.082561805060685237

# %%
res = model_selection.cross_val_score(
    linear_model.LogisticRegression(),
    Xo,
    ro,
    cv=10
)
sc.mean(res)
# Out:
# /home/ide/.virtualenvs/data/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.21057404391055007

# %% [markdown]
# rscv=model_selection.RandomizedSearchCV(
#     pipeline.make_pipeline(
#         preprocessing.StandardScaler(),
#         svm.SVC(),
#     ),
#     dict(
#         svc__C=sc.logspace(-5,5,100),#sc.stats.uniform(0,1),
#         svc__kernel=['linear','rbf', 'poly'],
#         svc__gamma=sc.logspace(-5,5,100),
#         svc__degree=sc.stats.randint(1,10)
#     ),
#     n_iter=5,
#     n_jobs=-1,
#     cv=10,
#     verbose=True,
# )
# rscv.fit(X,r)
# rscv.score(Xt,rt)

# %%
rscv=ELMClassifier(h=1000)
rscv.fit(X,r)
rscv.score(Xt,rt)

# %% [markdown]
# rscv.best_params_, rscv.best_score_

# %%
n=10
xs = [100*x//n for x in range(1,1+n)]
tra,tes=model_selection.validation_curve(
    ensemble.RandomForestClassifier(), 
    X, 
    r, 
    'n_estimators', 
    xs)
da=pd.DataFrame(sc.array([xs, sc.mean(tes,axis=1), sc.mean(tra,axis=1)]).T, columns=['x','tes','tra'])
gg.ggplot(da,gg.aes('x','tes'))+gg.geom_point()+gg.stat_smooth(method='loess')

# %%
n=10
xs = [3000*x//n for x in range(1,1+n)]
tra,tes=model_selection.validation_curve(
    ELMClassifier(), 
    X, 
    r, 
    'h', 
    xs)
da=pd.DataFrame(sc.array([xs, sc.mean(tes,axis=1), sc.mean(tra,axis=1)]).T, columns=['x','tes','tra'])
gg.ggplot(da,gg.aes('x','tes'))+gg.geom_point()+gg.stat_smooth(method='loess')

# %%
n=10
sca=30
xs = [[sca*x//n,] for x in range(1,1+n)]
tra,tes=model_selection.validation_curve(
    neural_network.MLPClassifier(solver='lbfgs', max_iter=10000), 
    X, 
    r, 
    'hidden_layer_sizes', 
    xs)
xs = [sca*x//n for x in range(1,1+n)]
da=pd.DataFrame(sc.array([xs, sc.mean(tes,axis=1), sc.mean(tra,axis=1)]).T, columns=['x','tes','tra'])
gg.ggplot(da,gg.aes('x','tes'))+gg.geom_point()+gg.stat_smooth(method='loess')

# %%
rscv=ELMClassifier(h=10, af=sc.special.expit)#lambda x: x)

# %%
rscv.fit(X,r)

# %%
rscv.score(Xt,rt)

# %%
W0=sc.stats.norm().rvs([X.shape[1],100])
X0=sc.tanh(W0.T@X.T)
W=sc.linalg.pinv(X0.T)@r

# %%
sc.sum(abs((W@sc.tanh(W0.T@X.T))==r))
